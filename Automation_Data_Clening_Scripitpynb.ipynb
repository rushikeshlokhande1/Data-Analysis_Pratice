# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshlokhande1/Data-Analysis_Pratice/blob/main/Automation_Data_Clening_Scripitpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %%
file=files.upload()
# Out:
#      <input type="file" id="files-c7b15a13-1885-42d5-8abe-7fa661eb8594" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7b15a13-1885-42d5-8abe-7fa661eb8594">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(next(iter(file)), encoding='latin1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.columns=df.columns.str.capitalize()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ordernumber       2823 non-null   int64
#  1   Quantityordered   2823 non-null   int64
#  2   Priceeach         2823 non-null   float64
#  3   Orderlinenumber   2823 non-null   int64
#  4   Sales             2823 non-null   float64
#  5   Orderdate         2823 non-null   object
#  6   Status            2823 non-null   object
#  7   Qtr_id            2823 non-null   int64
#  8   Month_id          2823 non-null   int64
#  9   Year_id           2823 non-null   int64
#  10  Productline       2823 non-null   object
#  11  Msrp              2823 non-null   int64
#  12  Productcode       2823 non-null   object
#  13  Customername      2823 non-null   object
#  14  Phone             2823 non-null   object
#  15  Addressline1      2823 non-null   object
# ...

# %%
df
# Out:
#       Ordernumber  Quantityordered  Priceeach  Orderlinenumber    Sales  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             Orderdate    Status  Qtr_id  Month_id  Year_id  ...  \
# ...

# %%
df.describe()
# Out:
#         Ordernumber  Quantityordered    Priceeach  Orderlinenumber  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               Sales       Qtr_id     Month_id     Year_id         Msrp
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull().sum()
# Out:
# Ordernumber            0
# Quantityordered        0
# Priceeach              0
# Orderlinenumber        0
# Sales                  0
# Orderdate              0
# Status                 0
# Qtr_id                 0
# Month_id               0
# Year_id                0
# Productline            0
# Msrp                   0
# Productcode            0
# Customername           0
# Phone                  0
# Addressline1           0
# Addressline2        2521
# City                   0
# State               1486
# Postalcode            76
# Country                0
# Territory           1074
# Contactlastname        0
# Contactfirstname       0
# Dealsize               0
# dtype: int64

# %%
for col in list(df.columns):
    null_count = df[col].isnull().sum()
    if null_count > len(df) * 0.5:
        df.drop(columns=col, inplace=True)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Ordernumber         0
# Quantityordered     0
# Priceeach           0
# Orderlinenumber     0
# Sales               0
# Orderdate           0
# Status              0
# Qtr_id              0
# Month_id            0
# Year_id             0
# Productline         0
# Msrp                0
# Productcode         0
# Customername        0
# Phone               0
# Addressline1        0
# City                0
# Postalcode          0
# Country             0
# Territory           0
# Contactlastname     0
# Contactfirstname    0
# Dealsize            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df = df.convert_dtypes()

# %%
for col in df.columns:

    if df[col].dtype in ['object', 'string']:

        if df[col].astype(str).str.contains(r'\$', regex=True, na=False).any():

            print("Currency Column:", col)

            df[col] = (
                df[col]
                .astype(str)
                .str.replace(r'[$,]', '', regex=True)
            )

# %%
for col in df.select_dtypes(include=['object','string']).columns:
  df[col]=df[col].str.capitalize()

# %%
for col in df.columns:
  if df[col].dtype in ['object','string']:
    temp=pd.to_datetime(df[col],errors='coerce')
    sucess_rate=temp.notna().mean()
    if sucess_rate>0.7:
      df[col]=temp
      print(f"{col} identy as date")
    else:
      print("No Date column")
# Out:
# Orderdate identy as date
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# No Date column
# /tmp/ipykernel_1483/1037226953.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp=pd.to_datetime(df[col],errors='coerce')
# /tmp/ipykernel_1483/1037226953.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp=pd.to_datetime(df[col],errors='coerce')
# ...

# %%
report = {
    "Rows": df.shape[0],
    "Columns": df.shape[1],
    "Missing Values": df.isnull().sum().sum(),
    "Duplicate Rows": df.duplicated().sum()
}

report
# Out:
# {'Rows': 1749,
#  'Columns': 23,
#  'Missing Values': np.int64(0),
#  'Duplicate Rows': np.int64(0)}

# %%
df.head(10)
# Out:
#     Ordernumber  Quantityordered  Priceeach  Orderlinenumber    Sales  \
# 1         10121               34      81.35                5   2765.9
# 2         10134               41      94.74                2  3884.34
# 6         10180               29      86.13                9  2497.77
# 7         10188               48      100.0                1  5512.32
# 9         10211               41      100.0               14  4708.44
# 10        10223               37      100.0                1  3965.66
# 14        10275               45      92.83                1  4177.35
# 16        10299               23      100.0                9  2597.39
# 17        10309               41      100.0                5  4394.38
# 20        10341               41      100.0                9  7737.93
#
#     Orderdate   Status  Qtr_id  Month_id  Year_id  ...  \
# 1  2003-05-07  Shipped       2         5     2003  ...
# 2  2003-07-01  Shipped       3         7     2003  ...
# ...
